# %%
# !pip install path.py

# %%
# !git clone https://github.com/titu1994/neural-image-assessment.git
# %cd neural-image-assessment
# Out:
# Cloning into 'neural-image-assessment'...
# remote: Enumerating objects: 178, done.
# remote: Total 178 (delta 0), reused 0 (delta 0), pack-reused 178 (from 1)
# Receiving objects: 100% (178/178), 21.51 MiB | 30.34 MiB/s, done.
# Resolving deltas: 100% (90/90), done.
# /content/neural-image-assessment

# %%
# Change to your folder path
# !python evaluate_mobilenet.py -dir /content/DoubleExposureDataset
# Out:
# 2025-05-26 13:12:30.006506: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748265150.037753    6245 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748265150.045631    6245 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-26 13:12:30.077382: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
controlnet_mean = (5.47439 + 5.42028 + 5.07374 + 4.98734 + 4.95152) / 5
sd_mean = (5.38844 + 5.20577 + 5.18983 + 5.10006 + 4.63455) / 5
real_mean = (4.49703 + 4.47299 + 4.01358 + 3.90067 + 3.79123 + 3.78271 + 3.39642 + 3.19825 + 2.92133 + 1.748) / 10
print("Controlnet:", controlnet_mean, "\nSD:", sd_mean, '\nReal:', real_mean)
# Out:
# Controlnet: 5.181454
# SD: 5.1037300000000005
# Real: 3.572221
